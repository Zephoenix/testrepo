# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# This notebook was created by Oluwabukolah Johnson in competion of the second module of the IBM Data Science program. In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# - NumPy
# - Pandas
# - TensorFlow

# %% [markdown]
# Data Science tools include:
#
# |S/N  |  Name |
# |---  |   --- |
# |1.   |  SAS |
# |2.  |MatPlotLib    |
# |3.   |Apache Spark |

# %% [markdown]
# The next cell includes arithmetric operations; using addition, subtraction, multiplication and division.

# %%
x = 3+4
y = 3*4
print (x,',',y)
# Out:
# 7 , 12

# %%
#Coverting minutes to hours just involves dividing by 60. Below is a conversion of 180 minutes to hours.
x = 180
y = x//60
print (x,' minutes', ' is equal to ', y,' hours')
# Out:
# 180  minutes  is equal to  3  hours

# %% [markdown]
# The objectives of this program include:
# 1. To learn to be a data scientist
# 2. to grow to be a data scientist
# 3. To grow and improve the data science community

# %% [markdown]
# My name is Oluwabukolah Johnson and I am the author of this program.
